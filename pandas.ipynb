# %%
"""what IS Pandas!

Pandas is an open-source Python library designed for data manipulation and analysis. It makes working with structured data fast, flexible, and intuitive - especially if you're dealing
with CSV files, Excel sheets, SQL tables, JSON, or APIs.

The two core data structures in Pandas are:

· Series : A 1D labeled array (like a column)
. DataFrame : A 2D labeled data structure (like a full spreadsheet or SQL table)

What Is a DataFrame?

A DataFrame is a two-dimensional, tabular data structure with labeled rows and columns. Think of it as a Python-native spreadsheet - but way more powerful and programmable.

Key Features:

· Label-based indexing
. Column-wise and row-wise operations
. Support for mixed data types
. Fast, vectorized operations (built on NumPy)


 """
import pandas as pd

# %%
df = pd.read_csv("deliveries.csv")

# %%
print(df)
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df.tail()
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 150455       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150456       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150457       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150458       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150459       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
#         over  ball        batsman    non_striker   bowler  is_super_over  ...  \
# 150455    20     2    Sachin Baby      CJ Jordan  B Kumar              0  ...
# 150456    20     3    Sachin Baby      CJ Jordan  B Kumar              0  ...
# 150457    20     4  Iqbal Abdulla    Sachin Baby  B Kumar              0  ...
# 150458    20     5    Sachin Baby  Iqbal Abdulla  B Kumar              0  ...
# 150459    20     6  Iqbal Abdulla    Sachin Baby  B Kumar              0  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150460 entries, 0 to 150459
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          150460 non-null  int64
#  1   inning            150460 non-null  int64
#  2   batting_team      150460 non-null  str
#  3   bowling_team      150460 non-null  str
#  4   over              150460 non-null  int64
#  5   ball              150460 non-null  int64
#  6   batsman           150460 non-null  str
#  7   non_striker       150460 non-null  str
#  8   bowler            150460 non-null  str
#  9   is_super_over     150460 non-null  int64
#  10  wide_runs         150460 non-null  int64
#  11  bye_runs          150460 non-null  int64
#  12  legbye_runs       150460 non-null  int64
#  13  noball_runs       150460 non-null  int64
#  14  penalty_runs      150460 non-null  int64
#  15  batsman_runs      150460 non-null  int64
# ...

# %%
df.describe()
# Out:
#             match_id         inning           over           ball  \
# count  150460.000000  150460.000000  150460.000000  150460.000000
# mean      318.281317       1.482188      10.142649       3.616483
# std       182.955531       0.501768       5.674338       1.807698
# min         1.000000       1.000000       1.000000       1.000000
# 25%       161.000000       1.000000       5.000000       2.000000
# 50%       319.000000       1.000000      10.000000       4.000000
# 75%       476.000000       2.000000      15.000000       5.000000
# max       636.000000       4.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  150460.000000  150460.000000  150460.000000  150460.000000
# mean        0.000538       0.037498       0.004885       0.022232
# std         0.023196       0.257398       0.114234       0.200104
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150460, step=1)

# %%
#indexing by rows and column
df[["match_id", "inning","bowling_team"]]
# Out:
#         match_id  inning                 bowling_team
# 0              1       1  Royal Challengers Bangalore
# 1              1       1  Royal Challengers Bangalore
# 2              1       1  Royal Challengers Bangalore
# 3              1       1  Royal Challengers Bangalore
# 4              1       1  Royal Challengers Bangalore
# ...          ...     ...                          ...
# 150455       636       2          Sunrisers Hyderabad
# 150456       636       2          Sunrisers Hyderabad
# 150457       636       2          Sunrisers Hyderabad
# 150458       636       2          Sunrisers Hyderabad
# 150459       636       2          Sunrisers Hyderabad
#
# [150460 rows x 3 columns]

# %%
df.iloc[2]
# Out:
# match_id                                      1
# inning                                        1
# batting_team                Sunrisers Hyderabad
# bowling_team        Royal Challengers Bangalore
# over                                          1
# ball                                          3
# batsman                               DA Warner
# non_striker                            S Dhawan
# bowler                                 TS Mills
# is_super_over                                 0
# wide_runs                                     0
# bye_runs                                      0
# legbye_runs                                   0
# noball_runs                                   0
# penalty_runs                                  0
# batsman_runs                                  4
# extra_runs                                    0
# total_runs                                    4
# player_dismissed                            NaN
# dismissal_kind                              NaN
# ...

# %%
list(df.iloc[1])
# Out:
# [np.int64(1),
#  np.int64(1),
#  'Sunrisers Hyderabad',
#  'Royal Challengers Bangalore',
#  np.int64(1),
#  np.int64(2),
#  'DA Warner',
#  'S Dhawan',
#  'TS Mills',
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  nan,
#  nan,
#  nan]

# %%
df[(df["batting_team"]=="Royal Challengers Bangalore") & (df["batsman"]== "CH Gayle")]
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 125            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 131            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 132            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 133            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 137            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# ...          ...     ...                          ...                  ...
# 150393       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150397       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150398       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150400       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150402       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
# ...

# %%
df[(df["batting_team"]=="Royal Challengers Bangalore") | (df["batsman"]== "CH Gayle")]
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 125            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 126            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 127            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 128            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 129            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# ...          ...     ...                          ...                  ...
# 150455       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150456       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150457       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150458       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150459       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
# ...

# %%
df[df["legbye_runs"]==1]
# Out:
#         match_id  inning                 batting_team  \
# 6              1       1          Sunrisers Hyderabad
# 238            1       2  Royal Challengers Bangalore
# 309            2       1               Mumbai Indians
# 383            2       2       Rising Pune Supergiant
# 540            3       1                Gujarat Lions
# ...          ...     ...                          ...
# 150337       636       2  Royal Challengers Bangalore
# 150351       636       2  Royal Challengers Bangalore
# 150446       636       2  Royal Challengers Bangalore
# 150451       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman  non_striker  \
# 6       Royal Challengers Bangalore     1     7       S Dhawan    DA Warner
# 238             Sunrisers Hyderabad    19     1       TS Mills    YS Chahal
# 309          Rising Pune Supergiant    11     1      AT Rayudu       N Rana
# ...

# %%
df[(df["bowler"].str.startswith("M")) & (df["ball"]==5) & (df["over"]==20) & (df["batsman"]=="BCJ Cutting")]
# Out:
#         match_id  inning         batting_team     bowling_team  over  ball  \
# 147198       622       2  Sunrisers Hyderabad  Kings XI Punjab    20     5
#
#             batsman   non_striker     bowler  is_super_over  ...  bye_runs  \
# 147198  BCJ Cutting  Yuvraj Singh  MM Sharma              0  ...         0
#
#         legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# 147198            0            0             0             1           0
#
#         total_runs  player_dismissed dismissal_kind fielder
# 147198           1               NaN            NaN     NaN
#
# [1 rows x 21 columns]

# %%
df[(df["bowler"].str.endswith("n")) ]
# Out:
#         match_id  inning                 batting_team  \
# 32             1       1          Sunrisers Hyderabad
# 33             1       1          Sunrisers Hyderabad
# 34             1       1          Sunrisers Hyderabad
# 35             1       1          Sunrisers Hyderabad
# 36             1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150449       636       2  Royal Challengers Bangalore
# 150450       636       2  Royal Challengers Bangalore
# 150451       636       2  Royal Challengers Bangalore
# 150452       636       2  Royal Challengers Bangalore
# 150453       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball      batsman   non_striker  \
# 32      Royal Challengers Bangalore     6     1     S Dhawan  MC Henriques
# 33      Royal Challengers Bangalore     6     2     S Dhawan  MC Henriques
# 34      Royal Challengers Bangalore     6     3     S Dhawan  MC Henriques
# ...

# %%
df[df["batsman"].isin(["Iqbal Abdulla","Sachin Baby"])]  #isin mean that the "Iqbal Abdulla","Sachin Baby" these both are present in the column or not
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 208            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 209            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 211            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 1066           5       1  Royal Challengers Bangalore     Delhi Daredevils
# 1067           5       1  Royal Challengers Bangalore     Delhi Daredevils
# ...          ...     ...                          ...                  ...
# 150455       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150456       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150457       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150458       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150459       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
# ...

# %%
#update data
df.loc[df["bowler"]=="Sachin Baby"]
# Out:
#         match_id  inning     batting_team                 bowling_team  over  \
# 146810       620       2    Gujarat Lions  Royal Challengers Bangalore    19
# 146811       620       2    Gujarat Lions  Royal Challengers Bangalore    19
# 146812       620       2    Gujarat Lions  Royal Challengers Bangalore    19
# 146813       620       2    Gujarat Lions  Royal Challengers Bangalore    19
# 148042       626       2  Kings XI Punjab  Royal Challengers Bangalore    13
# 148043       626       2  Kings XI Punjab  Royal Challengers Bangalore    13
# 148044       626       2  Kings XI Punjab  Royal Challengers Bangalore    13
# 148045       626       2  Kings XI Punjab  Royal Challengers Bangalore    13
# 148046       626       2  Kings XI Punjab  Royal Challengers Bangalore    13
# 148047       626       2  Kings XI Punjab  Royal Challengers Bangalore    13
#
#         ball         batsman     non_striker       bowler  is_super_over  ...  \
# ...

# %%
#update data
df.loc[df["bowler"]=="Sachin Baby", "over"]=20  """.loc means the location-based indexer of a DataFrame.
                                                    It selects only those rows where the "bowler" column contains "Sachin Baby".
                                                    When we use .loc with an assignment, only the selected rows are updated in the DataFrame."""

# %%
df.loc[df["bowler"]=="Sachin Baby"]
# Out:
#         match_id  inning     batting_team                 bowling_team  over  \
# 146810       620       2    Gujarat Lions  Royal Challengers Bangalore    20
# 146811       620       2    Gujarat Lions  Royal Challengers Bangalore    20
# 146812       620       2    Gujarat Lions  Royal Challengers Bangalore    20
# 146813       620       2    Gujarat Lions  Royal Challengers Bangalore    20
# 148042       626       2  Kings XI Punjab  Royal Challengers Bangalore    20
# 148043       626       2  Kings XI Punjab  Royal Challengers Bangalore    20
# 148044       626       2  Kings XI Punjab  Royal Challengers Bangalore    20
# 148045       626       2  Kings XI Punjab  Royal Challengers Bangalore    20
# 148046       626       2  Kings XI Punjab  Royal Challengers Bangalore    20
# 148047       626       2  Kings XI Punjab  Royal Challengers Bangalore    20
#
#         ball         batsman     non_striker       bowler  is_super_over  ...  \
# ...

# %%
df.dropna()
# Out:
#         match_id  inning                 batting_team  \
# 11             1       1          Sunrisers Hyderabad
# 64             1       1          Sunrisers Hyderabad
# 94             1       1          Sunrisers Hyderabad
# 165            1       2  Royal Challengers Bangalore
# 199            1       2  Royal Challengers Bangalore
# ...          ...     ...                          ...
# 150402       636       2  Royal Challengers Bangalore
# 150422       636       2  Royal Challengers Bangalore
# 150438       636       2  Royal Challengers Bangalore
# 150448       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball         batsman   non_striker  \
# 11      Royal Challengers Bangalore     2     5       DA Warner      S Dhawan
# 64      Royal Challengers Bangalore    11     3        S Dhawan  MC Henriques
# 94      Royal Challengers Bangalore    16     2    MC Henriques  Yuvraj Singh
# ...

# %%
df.fillna(0)
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
df
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...
