# %%
"""_______________________________Random Variables__________________________

A Random Variable X is a function that assigns a real number to each outcome in
the sample space of a random experiment.

__________________________________Random Variables___________________________

. Discrete Random Variable: A random variable that takes on a countable
number of distinct values.
. Continuous Random Variable: A random variable that can take on any value
within a given range or interval.
PROBAILITY

Probability measures the likelihood of a particular outcome or event occurring. It
is typically expressed as a number between 0 and 1, where 0 indicates
impossibility (event will not occur) and 1 indicates certainty (event will occur).

p(A) = Number of times A occurs/Total number of possible outcomes


_______________________________PROBAILITY DISTRIBUTION___________________________________

Probability dictributions describe how the probabilities of different outcomes are
distributed over the sample space of a random variable.

Discrete Probability Distributions
Continuous Probability Distributions

____________________________Probability Distribution Functions________________________
- PDF, PMF & CDF
-->>PDF: this is work on the continious data (how data is distributed over continuous values.)
-->>PMF: probability of each exact discrete value.
-->>CDF: Both continuous and discrete distributions.


Probability Density Function (PDF), Probability Mass Function (PMF),
and Cumulative Density Function (CDF)

"""
# Out:
# '_______________________________Random Variables__________________________\n\nA Random Variable X is a function that assigns a real number to each outcome in\nthe sample space of a random experiment.\n\n__________________________________Random Variables___________________________\n\n. Discrete Random Variable: A random variable that takes on a countable\nnumber of distinct values.\n. Continuous Random Variable: A random variable that can take on any value\nwithin a given range or interval.\nPROBAILITY\n\nProbability measures the likelihood of a particular outcome or event occurring. It\nis typically expressed as a number between 0 and 1, where 0 indicates\nimpossibility (event will not occur) and 1 indicates certainty (event will occur).\n\np(A) = Number of times A occurs/Total number of possible outcomes\n\n\n_______________________________PROBAILITY DISTRIBUTION___________________________________\n\nProbability dictributions describe how the probabilities of different outcomes are\
# ...

# %%
"""NORMAL DISTRIBUTION

Normal distribution:
It known as the Gaussian distribution, is a probability distribution that is symmetric about the mean, showing that data near the mean are more
frequent in occurrence than data far from the mean. In graph form, normal distribution will appear as a bell  curve.

"""
