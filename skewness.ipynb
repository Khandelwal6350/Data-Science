# %%
"""SKEWNESS

Skewness measures the asymmetry of the distribution.
A skewness value of 0 indicates a perfectly symmetrical distribution.
. Positive skewness indicates that the distribution is skewed to the right (i.e
tail is longer on the right), while negative skewness indicates a left skew
the tail is longer on the left).

Skewness =


Frequency & Cumulative Distribution

. A frequency distribution is a table that shows the number of occurrences of
different values in a dataset.
. A cumulative distribution shows the accumulation of frequencies up to a
certain point. It is obtained by adding up the frequencies as you move thi
the values.


"""
# Out:
# 'SKEWNESS\n\nSkewness measures the asymmetry of the distribution.\nA skewness value of 0 indicates a perfectly symmetrical distribution.\n. Positive skewness indicates that the distribution is skewed to the right (i.e\ntail is longer on the right), while negative skewness indicates a left skew\nthe tail is longer on the left).\n\nSkewness =\n\n\nFrequency & Cumulative Distribution\n\n. A frequency distribution is a table that shows the number of occurrences of\ndifferent values in a dataset.\n. A cumulative distribution shows the accumulation of frequencies up to a\ncertain point. It is obtained by adding up the frequencies as you move thi\nthe values.\n\n\n'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("titanic_like_dataset_120_rows.csv")

# %%
df.head(3)
# Out:
#    survived  pclass     sex  age  sibsp  parch   fare embarked   class    who  \
# 0         1       1    male   16      4      2  77.04        C  Second    man
# 1         1       2  female   24      3      5   8.05        C  Second  woman
# 2         1       1    male    7      3      0  53.78        S   First  child
#
#    adult_male deck  embark_town alive  alone
# 0        True    D   Queenstown    no   True
# 1       False    B  Southampton   yes  False
# 2       False    A    Cherbourg   yes  False
